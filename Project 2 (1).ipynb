# %% [markdown]
# # Project 2
# **Author:** Connor Pawlowski
#
# **# Wine Quality Data Analysis**
#
# **Python Data Analysis Project**

# %%
import pandas as pd

df = pd.read_csv('winequality-red.csv')

df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
categorical_col = 'quality'
numeric_cols = ['alcohol', 'pH']

print("Overall Statistics:\n")
for col in numeric_cols:
    print(f"{col}:")
    print(f"  Mean: {df[col].mean():.2f}")
    print(f"  Max: {df[col].max():.2f}")
    print(f"  Min: {df[col].min():.2f}")
    print(f"  Standard Deviation: {df[col].std():.2f}")
    print(f"  Range: {df[col].max() - df[col].min():.2f}")
    print(f"  Median: {df[col].median():.2f}\n")

print("Statistics by Quality:\n")
for q in sorted(df[categorical_col].unique()):
    subset = df[df[categorical_col] == q]
    print(f"Quality {q}:")
    for col in numeric_cols:
        print(f"  {col}: Mean={subset[col].mean():.2f}, Max={subset[col].max():.2f}, Min={subset[col].min():.2f}, Std={subset[col].std():.2f}, Range={subset[col].max() - subset[col].min():.2f}, Median={subset[col].median():.2f}")
    print()
# Out:
# Overall Statistics:
#
# alcohol:
#   Mean: 10.42
#   Max: 14.90
#   Min: 8.40
#   Standard Deviation: 1.07
#   Range: 6.50
#   Median: 10.20
#
# pH:
#   Mean: 3.31
#   Max: 4.01
#   Min: 2.74
#   Standard Deviation: 0.15
#   Range: 1.27
#   Median: 3.31
#
# Statistics by Quality:
#
# Quality 3:
#   alcohol: Mean=9.96, Max=11.00, Min=8.40, Std=0.82, Range=2.60, Median=9.93
#   pH: Mean=3.40, Max=3.63, Min=3.16, Std=0.14, Range=0.47, Median=3.39
#
# Quality 4:
#   alcohol: Mean=10.27, Max=13.10, Min=9.00, Std=0.93, Range=4.10, Median=10.00
#   pH: Mean=3.38, Max=3.90, Min=2.74, Std=0.18, Range=1.16, Median=3.37
#
# Quality 5:
#   alcohol: Mean=9.90, Max=14.90, Min=8.50, Std=0.74, Range=6.40, Median=9.70
#   pH: Mean=3.30, Max=3.74, Min=2.88, Std=0.15, Range=0.86, Median=3.30
#
# Quality 6:
#   alcohol: Mean=10.63, Max=14.00, Min=8.40, Std=1.05, Range=5.60, Median=10.50
#   pH: Mean=3.32, Max=4.01, Min=2.86, Std=0.15, Range=1.15, Median=3.32
#
# Quality 7:
# ...

# %% [markdown]
# ## Task 2: Basic Statistics
#
# ### Overall Statistics
# **Alcohol**
# - Mean: 10.42
# - Max: 14.90
# - Min: 8.40
# - Standard Deviation: 1.07
# - Range: 6.50
# - Median: 10.20
#
# **pH**
# - Mean: 3.31
# - Max: 4.01
# - Min: 2.74
# - Standard Deviation: 0.15
# - Range: 1.27
# - Median: 3.31
#
# ### Statistics by Wine Quality
#
# **Quality 3**
# - Alcohol: Mean=9.96, Max=11.00, Min=8.40, Std=0.82, Range=2.60, Median=9.93
# - pH: Mean=3.40, Max=3.63, Min=3.16, Std=0.14, Range=0.47, Median=3.39
#
# **Quality 4**
# - Alcohol: Mean=10.27, Max=13.10, Min=9.00, Std=0.93, Range=4.10, Median=10.00
# - pH: Mean=3.38, Max=3.90, Min=2.74, Std=0.18, Range=1.16, Median=3.37
#
# **Quality 5**
# - Alcohol: Mean=9.90, Max=14.90, Min=8.50, Std=0.74, Range=6.40, Median=9.70
# - pH: Mean=3.30, Max=3.74, Min=2.88, Std=0.15, Range=0.86, Median=3.30
#
# **Quality 6**
# - Alcohol: Mean=10.63, Max=14.00, Min=8.40, Std=1.05, Range=5.60, Median=10.50
# - pH: Mean=3.32, Max=4.01, Min=2.86, Std=0.15, Range=1.15, Median=3.32
#
# **Quality 7**
# - Alcohol: Mean=11.47, Max=14.00, Min=9.20, Std=0.96, Range=4.80, Median=11.50
# - pH: Mean=3.29, Max=3.78, Min=2.92, Std=0.15, Range=0.86, Median=3.28
#
# **Quality 8**
# - Alcohol: Mean=12.09, Max=14.00, Min=9.80, Std=1.22, Range=4.20, Median=12.15
# - pH: Mean=3.27, Max=3.72, Min=2.88, Std=0.20, Range=0.84, Median=3.23

# %% [markdown]
# ## Task 3: Plotting Basic Distributions
# - Scatter plot: alcohol vs pH
# - Histograms: alcohol and pH
# - Histograms by category: alcohol for each wine quality

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='alcohol', y='pH', hue='quality', palette='viridis', s=60)
plt.title('Scatter Plot of Alcohol vs pH by Wine Quality')
plt.xlabel('Alcohol (%)')
plt.ylabel('pH')
plt.legend(title='Quality')
plt.show()

# %% [markdown]
# ### Histograms of Numeric Columns with Mean and Median
# The histograms below show the distribution of alcohol and pH values. Red dashed lines indicate the mean, and green dotted lines indicate the median.

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['alcohol'], bins=15, kde=False, color='skyblue')


mean_alc = df['alcohol'].mean()
median_alc = df['alcohol'].median()
plt.axvline(mean_alc, color='red', linestyle='dashed', linewidth=2, label=f'Mean: {mean_alc:.2f}')
plt.axvline(median_alc, color='green', linestyle='dotted', linewidth=2, label=f'Median: {median_alc:.2f}')

plt.title('Distribution of Alcohol with Mean and Median')
plt.xlabel('Alcohol (%)')
plt.ylabel('Count')
plt.legend()
plt.show()


plt.figure(figsize=(8,5))
sns.histplot(df['pH'], bins=15, kde=False, color='salmon')


mean_pH = df['pH'].mean()
median_pH = df['pH'].median()
plt.axvline(mean_pH, color='red', linestyle='dashed', linewidth=2, label=f'Mean: {mean_pH:.2f}')
plt.axvline(median_pH, color='green', linestyle='dotted', linewidth=2, label=f'Median: {median_pH:.2f}')

plt.title('Distribution of pH with Mean and Median')
plt.xlabel('pH')
plt.ylabel('Count')
plt.legend()
plt.show()
# Out:
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
qualities = sorted(df['quality'].unique())
plt.figure(figsize=(12,8))

for q in qualities:
    subset = df[df['quality'] == q]
    sns.histplot(subset['alcohol'], bins=10, kde=False, label=f'Quality {q}', alpha=0.6)

plt.title('Distribution of Alcohol by Wine Quality')
plt.xlabel('Alcohol (%)')
plt.ylabel('Count')
plt.legend(title='Quality')
plt.show()
# Out:
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ##Task 4: Observations and Conclusions
#
# The overall statistics show that these wines have an average alcohol concentration of 10.4%, with a range of 8.4% to 14.9%.  The majority of wines are near the average pH of 3.31, with values ranging from 2.74 to 4.01. This indicates that the dataset's wines have a modest range of acidity and alcohol content. When we look at the data by wine quality, we see a number of trends. Higher-quality wines usually have higher alcohol content. For example, wines rated an 8 have an average alcohol concentration of about 12%, whilst wines rated a 3 or 4 have lower averages, closer to 10%. Although the pH values are generally similar across quality levels, higher quality wines have a somewhat lower pH (less acidity).
#
# Although there isn't much of a correlation between pH and alcohol, the scatter plot indicates that higher-quality wines typically contain slightly more alcohol. With a mean of 10.42 and a median of 10.2, the alcohol histogram is skewed to the right. Additionally, the mean and median of the pH histogram are equal, making it symmetrical. The histograms also show that the distribution of alcohol shifts as quality rises and that the majority of wines fall into the middle quality range (5 and 6). Overall, these findings make sense and indicate that, although pH varies less, alcohol may play a role in wine quality. The study did include other variables many of which would be wise to test analyze similar to alcohol and pH. Some possible variables to examine are fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, and/or sulphates. 	Overall, these findings make sense and indicate that, although pH varies less, alcohol may play a role in wine quality.
